# %% [markdown]
# The purpose of this code is to extract the pecan street data in a usable form. After you mount your google drive, you will need to change the file paths used.

# %%
#add in drive mount

# %%
# importing the "tarfile" module
import tarfile

# open file
file = tarfile.open('/content/drive/MyDrive/50_ResidentialPowerDisaggregation_SD_Fall23/1.2 Software/Colab Notebooks/ML Models/Andrew/15minute_data_california.tar.gz')

# print file names
print(file.getnames())

# extracting file
file.extractall('/content/drive/MyDrive/50_ResidentialPowerDisaggregation_SD_Fall23/1.2 Software/Colab Notebooks/ML Models/Andrew')

# extracting a specific file
file.extract('15minute_data_california/15minute_data_california.csv', '/content/drive/MyDrive/50_ResidentialPowerDisaggregation_SD_Fall23/1.2 Software/Colab Notebooks/ML Models/Andrew')

file.close()

import pandas as pd
df = pd.read_csv ('/content/drive/MyDrive/50_ResidentialPowerDisaggregation_SD_Fall23/1.2 Software/Colab Notebooks/ML Models/15minute_data_california/15minute_data_california.csv')

df
# Out:
# ['15minute_data_california', '15minute_data_california/15minute_data_california.csv', '15minute_data_california/metadata.csv']
