# %% [markdown]
# ## Installs

# %%
# !pip install pandas==0.25.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 76.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install --no-deps git+https://github.com/nilmtk/nilmtk.git
# Out:
# ...
#   Cloning https://github.com/nilmtk/nilmtk.git to /tmp/pip-req-build-g52xr5n2
#   Running command git clone --filter=blob:none --quiet https://github.com/nilmtk/nilmtk.git /tmp/pip-req-build-g52xr5n2
#   Resolved https://github.com/nilmtk/nilmtk.git to commit b2c514479cef478cab872cb635056da08d5352a1
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nilmtk: filename=nilmtk-0.4.0.dev1+git.b2c5144-py3-none-any.whl size=279173 sha256=9704c8ad9600886c7ee587c7f6858ac7982e6c891d61f8cae79b749acf42ed11
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lgei26t3/wheels/a0/b7/fe/1723c5ee312e47a937a0d9b208cfac5de4b98e46f91b091878
# Successfully built nilmtk
# ...

# %%
# !pip install git+https://github.com/nilmtk/nilm_metadata.git
# Out:
# ...
#   Cloning https://github.com/nilmtk/nilm_metadata.git to /tmp/pip-req-build-sju3th5p
#   Running command git clone --filter=blob:none --quiet https://github.com/nilmtk/nilm_metadata.git /tmp/pip-req-build-sju3th5p
#   Resolved https://github.com/nilmtk/nilm_metadata.git to commit 7ed4bab9062d04cb35c6b6000b451715dc5ab4af
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nilm-metadata: filename=nilm_metadata-0.2.5-py3-none-any.whl size=24340 sha256=a3a440b5a217bd432376093203277e6b7dab516954d9218e255f3510def8511c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tmr7pn6x/wheels/99/fa/8f/432d56eeee16b00889fdbe5f6a11902ec54a55450fbf98b70b
# Successfully built nilm-metadata
# ...

# %%
# !pip install hmmlearn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 4.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nilmtk 0.4.0.dev1+git.b2c5144 requires jupyterlab, which is not installed.
# nilmtk 0.4.0.dev1+git.b2c5144 requires matplotlib==3.1.3, but you have matplotlib 3.7.1 which is incompatible.
# nilmtk 0.4.0.dev1+git.b2c5144 requires networkx==2.1, but you have networkx 3.2 which is incompatible.
# nilmtk 0.4.0.dev1+git.b2c5144 requires numpy<1.20.0,>=1.13.3, but you have numpy 1.23.5 which is incompatible.
# nilmtk 0.4.0.dev1+git.b2c5144 requires pandas==0.25.3, but you have pandas 1.5.3 which is incompatible.
# ...

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nilmtk import DataSet, HDFDataStore
from nilmtk.disaggregate import CO

# Set the path to the CSV file
file_path = '/content/drive/MyDrive/50_ResidentialPowerDisaggregation_SD_Fall23/1.2 Software/Colab Notebooks/ML Models/Andrew/MLData0.csv'

# Load CSV data into a df
data = pd.read_csv(file_path)

# Preprocess the timestamp column
data['timestamp'] = pd.to_datetime(data['timestamp'])
data['Hour'] = data['timestamp'].dt.hour
data['DayOfWeek'] = data['timestamp'].dt.dayofweek
data['Month'] = data['timestamp'].dt.month

# Select features and targets
X = data[['Hour', 'DayOfWeek', 'Month', 'Total']]
y = data[['Washer', 'BlowerGH', 'Lights', 'BlowerBed', 'CompGH', 'CompBed', 'Dryer', 'Recs1', 'Recs2', 'WaterHeater']]

##convert data to h5 file named disag??

# Create NILMTK DataSet objects
train_dataset = DataSet('/content/disag.h5')
new_dataset = DataSet(new_data)

# Initialize CombinatorialOptimisation class
co = CO()

# Train the model on the training dataset
co.train(train_dataset)

# Disaggregate the new data
disaggregated_data = co.disaggregate(new_dataset)

# Plot the disaggregated data
disaggregated_data.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-888b33dc5c9e> in <cell line: 24>()
#      22
#      23 # Convert your data to the NILMTK format using an HDFDataStore
# ---> 24 store = HDFDataStore('disag.h5')
#      25 store.put(key='building1', value=data)
#      26
#
# /usr/local/lib/python3.10/dist-packages/nilmtk/docinherit.py in f(*args, **kwargs)
#      51         def f(*args, **kwargs):
#      52             if obj:
# ---> 53                 return self.mthd(obj, *args, **kwargs)
#      54             else:
#      55                 return self.mthd(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/nilmtk/datastore/hdfdatastore.py in __init__(self, filename, mode)
#      16     def __init__(self, filename, mode="r"):
#      17         if mode in [ "r", "a" ] and not isfile(filename):
# ...
